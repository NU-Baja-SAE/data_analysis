# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# plot the data in the csv file data_12.csv
data = pd.read_csv('data_10-16/data/ECVT_DATA/data_9.csv')
plt.plot(data['rpm'][2000:])
plt.plot(data['sheavePos'][2000:] * 10)
plt.plot(data['wheel_rpm'][2000:])
plt.show()
