# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# plot the data in the csv file data_12.csv
data = pd.read_csv('data/data_12.csv')
plt.plot(data['rpm'])
plt.plot(data['sheavePos'] * 10)
plt.show()
